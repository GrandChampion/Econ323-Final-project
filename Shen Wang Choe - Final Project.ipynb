# %% [markdown]
# # **Final project**
# ## Team member
# |Name|Student Number|Section #|
# |----|--------------|-------|
# |Yiran Shen|48907570|004|
# |Rylee Wang|95006185|004|
# |Yeongu Choe|77672566|004|

# %%
# Importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importing CSV data
rawHomeRestrictionData = pd.read_csv("./src/stay-at-home-covid.csv")
rawFaceCoveringData = pd.read_csv("./src/face-covering-policies-covid.csv")
rawInternationalTravelControlData = pd.read_csv("./src/international-travel-covid.csv")
monthlyCanadaHotelInfo = pd.read_csv("./src/MonthlyCanadaHotel.csv")
unemployment = pd.read_csv("./src/Unemployment(2019,2020).csv")
rawInboundTourism = pd.read_csv("./src/Inbound tourism - OECD.csv")
rawOutboundTourism = pd.read_csv("./src/Outbound tourism - OECD.csv")
rawTouristExpenditure = pd.read_csv("./src/Tourist Expenditure - OECD.csv")

# %%
# Inbound tourist numbers of Canada, Japan, Korea, Mexico, USA
inboundTourism = rawInboundTourism.loc[rawInboundTourism["VARIABLE"] ==
                                    "INB_ARRIVALS_TOTAL"][["Country", "YEAR", "Value"]].reset_index()
canada2019Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2019)].loc[(inboundTourism["Country"] == "Canada")]["Value"].to_string().split()[1])
canada2020Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2020)].loc[(inboundTourism["Country"] == "Canada")]["Value"].to_string().split()[1])
canada2021Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2021)].loc[(inboundTourism["Country"] == "Canada")]["Value"].to_string().split()[1])

japan2019Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2019)].loc[(inboundTourism["Country"] == "Japan")]["Value"].to_string().split()[1])
japan2020Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2020)].loc[(inboundTourism["Country"] == "Japan")]["Value"].to_string().split()[1])
japan2021Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2021)].loc[(inboundTourism["Country"] == "Japan")]["Value"].to_string().split()[1])

korea2019Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2019)].loc[(inboundTourism["Country"] == "Korea")]["Value"].to_string().split()[1])
korea2020Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2020)].loc[(inboundTourism["Country"] == "Korea")]["Value"].to_string().split()[1])
korea2021Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2021)].loc[(inboundTourism["Country"] == "Korea")]["Value"].to_string().split()[1])

mexico2019Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2019)].loc[(inboundTourism["Country"] == "Mexico")]["Value"].to_string().split()[1])
mexico2020Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2020)].loc[(inboundTourism["Country"] == "Mexico")]["Value"].to_string().split()[1])
mexico2021Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2021)].loc[(inboundTourism["Country"] == "Mexico")]["Value"].to_string().split()[1])

us2019Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2019)].loc[(inboundTourism["Country"] == "United States")]["Value"].to_string().split()[1])
us2020Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2020)].loc[(inboundTourism["Country"] == "United States")]["Value"].to_string().split()[1])
us2021Inbound = int(inboundTourism.loc[(inboundTourism["YEAR"] == 2021)].loc[(inboundTourism["Country"] == "United States")]["Value"].to_string().split()[1])

# %%
# Outbound tourist numbers of Japan, Korea, Mexico, USA
outboundTourism = rawOutboundTourism.loc[rawOutboundTourism["VARIABLE"] =="OBND_DEP_TOTAL"][["Year", "Country", "Value"]]

japan2019Outbound = int(outboundTourism.loc[(outboundTourism["Year"] == 2019)].loc[(outboundTourism["Country"] == "Japan")]["Value"])
japan2020Outbound = int(outboundTourism.loc[(outboundTourism["Year"] == 2020)].loc[(outboundTourism["Country"] == "Japan")]["Value"])

korea2019Outbound = int(outboundTourism.loc[(outboundTourism["Year"] == 2019)].loc[(outboundTourism["Country"] == "Korea")]["Value"])
korea2020Outbound = int(outboundTourism.loc[(outboundTourism["Year"] == 2020)].loc[(outboundTourism["Country"] == "Korea")]["Value"])

mexico2019Outbound = int(outboundTourism.loc[(outboundTourism["Year"] == 2019)].loc[(outboundTourism["Country"] == "Mexico")]["Value"])
mexico2020Outbound = int(outboundTourism.loc[(outboundTourism["Year"] == 2020)].loc[(outboundTourism["Country"] == "Mexico")]["Value"])

us2019Outbound = int(outboundTourism.loc[(outboundTourism["Year"] == 2019)].loc[(outboundTourism["Country"] == "United States")]["Value"])
us2020Outbound = int(outboundTourism.loc[(outboundTourism["Year"] == 2020)].loc[(outboundTourism["Country"] == "United States")]["Value"])

# %%
# Tourist expenditure in USD of Canada, China, Japan, Korea, Mexico, USA
touristExpenditure = rawTouristExpenditure.loc[rawTouristExpenditure["Variable"] =="Total international receipts"][["Year","Country","Variable","Value","CUR"]].reset_index()


canada2019Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2019)].loc[(touristExpenditure["Country"] == "Canada")]["Value"])
canada2020Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2020)].loc[(touristExpenditure["Country"] == "Canada")]["Value"])
canada2021Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2021)].loc[(touristExpenditure["Country"] == "Canada")]["Value"])

china2019Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2019)].loc[(touristExpenditure["Country"] == "China (People's Republic of)")]["Value"])

japan2019Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2019)].loc[(touristExpenditure["Country"] == "Japan")]["Value"])
japan2020Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2020)].loc[(touristExpenditure["Country"] == "Japan")]["Value"])

korea2019Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2019)].loc[(touristExpenditure["Country"] == "Korea")]["Value"])
korea2020Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2020)].loc[(touristExpenditure["Country"] == "Korea")]["Value"])

mexico2019Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2019)].loc[(touristExpenditure["Country"] == "Mexico")]["Value"])
mexico2020Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2020)].loc[(touristExpenditure["Country"] == "Mexico")]["Value"])

us2019Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2019)].loc[(touristExpenditure["Country"] == "United States")]["Value"])
us2020Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2020)].loc[(touristExpenditure["Country"] == "United States")]["Value"])
us2021Expenditure = int(touristExpenditure.loc[(touristExpenditure["Year"] == 2021)].loc[(touristExpenditure["Country"] == "United States")]["Value"])

# %% [markdown]
# ## **Inbound, Outbound, Tourist Expenditure Visualization**

# %%
categories = ['USA', 'Mexico', 'Japan', 'Korea']
inbound2019List = [us2019Inbound, mexico2019Inbound, japan2019Inbound, korea2019Inbound]
inbound2020List = [us2020Inbound, mexico2020Inbound, japan2020Inbound, korea2020Inbound]
outbound2019List = [us2019Outbound, mexico2019Outbound, japan2019Outbound, korea2019Outbound]
outbound2020List = [us2020Outbound, mexico2020Outbound, japan2020Outbound, korea2020Outbound]
expenditure2019List = [us2019Expenditure,mexico2019Expenditure,japan2019Expenditure,korea2019Expenditure]
expenditure2020List = [us2020Expenditure,mexico2020Expenditure,japan2020Expenditure,korea2020Expenditure]

# Create horizontal bar chart
fig, (inboundGraph, outboundGraph, expenditureGraph) = plt.subplots(1, 3,figsize=(18, 4))

# Inbound Graph
inboundGraph.barh(categories, inbound2019List, height=0.25, align='edge')
inboundGraph.barh(categories, inbound2020List, height=-0.25, align='edge')
inboundGraph.set_title("Inbound Travel")
inboundGraph.set_xlabel("Number")
inboundGraph.set_ylabel("Country")
inboundGraph.legend(['2019', "2020"])

# Outbound Graph
outboundGraph.barh(categories, outbound2019List, height=0.25, align='edge')
outboundGraph.barh(categories, outbound2020List, height=-0.25, align='edge')
outboundGraph.set_title("Outbound Travel")
outboundGraph.set_xlabel("Number")
outboundGraph.legend(['2019', "2020"])

# Expenditure Graph
expenditureGraph.barh(categories, expenditure2019List, height=0.25, align='edge')
expenditureGraph.barh(categories, expenditure2020List, height=-0.25, align='edge')
expenditureGraph.set_title("Tourist Expenditures")
expenditureGraph.set_xlabel("USD")
expenditureGraph.legend(['2019', "2020"])

# Show plot
plt.show()

# %% [markdown]
# ## **Face covering policy and number or tourists**

# %%
# Face Covering Policies by country and year
# 0: No policy
# 1: Recommended by government
# 2: Required in some public spaces
# 3: Required in all public spaces
# 4: Required outdoor all times
us2020FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "United States")].iloc[:366]["facial_coverings"].mean()
us2021FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "United States")].iloc[366:731]["facial_coverings"].mean()
us2022FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "United States")].iloc[731:1096]["facial_coverings"].mean()
canada2020FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "Canada")].iloc[:366]["facial_coverings"].mean()
canada2021FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "Canada")].iloc[366:731]["facial_coverings"].mean()
canada2022FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "Canada")].iloc[731:1096]["facial_coverings"].mean()
mexico2020FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "Mexico")].iloc[:366]["facial_coverings"].mean()
mexico2021FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "Mexico")].iloc[366:731]["facial_coverings"].mean()
mexico2022FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "Mexico")].iloc[731:1096]["facial_coverings"].mean()
brazil2020FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "Brazil")].iloc[:366]["facial_coverings"].mean()
brazil2021FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "Brazil")].iloc[366:731]["facial_coverings"].mean()
brazil2022FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "Brazil")].iloc[731:1096]["facial_coverings"].mean()
china2020FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "China")].iloc[:366]["facial_coverings"].mean()
china2021FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "China")].iloc[366:731]["facial_coverings"].mean()
china2022FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "China")].iloc[731:1096]["facial_coverings"].mean()
korea2020FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "South Korea")].iloc[:366]["facial_coverings"].mean()
korea2021FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "South Korea")].iloc[366:731]["facial_coverings"].mean()
korea2022FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "South Korea")].iloc[731:1096]["facial_coverings"].mean()
japan2020FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "Japan")].iloc[:366]["facial_coverings"].mean()
japan2021FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "Japan")].iloc[366:731]["facial_coverings"].mean()
japan2022FaceCoveringPolicy = rawFaceCoveringData.loc[(
    rawFaceCoveringData["Entity"] == "Japan")].iloc[731:1096]["facial_coverings"].mean()

fcpDataFrame = pd.DataFrame({
    "Country": ["USA", "USA",
                "Canada", "Canada",
                "Mexico", "Mexico",
                "Korea", "Korea",
                "Japan", "Japan"],
    "Year": [2020, 2021,
             2020, 2021,
             2020, 2021,
             2020, 2021,
             2020, 2021],
    "Face covering policy (avg)": [us2020FaceCoveringPolicy, us2021FaceCoveringPolicy,
                                   canada2020FaceCoveringPolicy, canada2021FaceCoveringPolicy,
                                   mexico2020FaceCoveringPolicy, mexico2021FaceCoveringPolicy,
                                   korea2020FaceCoveringPolicy, korea2021FaceCoveringPolicy,
                                   japan2020FaceCoveringPolicy, japan2021FaceCoveringPolicy],
    "Number of In-bound Tourists": [us2020Inbound, us2021Inbound,
                                    canada2020Inbound, canada2020Inbound,
                                    mexico2020Inbound, mexico2021Inbound,
                                    korea2020Inbound, korea2021Inbound,
                                    japan2020Inbound, japan2021Inbound]
})
fcpDataFrame
# Out:
#   Country  Year  Face covering policy (avg)  Number of In-bound Tourists
# 0     USA  2020                    3.040984                     53556920
# 1     USA  2021                    2.934247                     46344402
# 2  Canada  2020                    1.633880                      5068000
# 3  Canada  2021                    3.000000                      5068000
# 4  Mexico  2020                    2.830601                     51128042
# 5  Mexico  2021                    3.819178                     55301421
# 6   Korea  2020                    1.653005                      2519118
# 7   Korea  2021                    3.000000                       967003
# 8   Japan  2020                    0.836066                      4115828
# 9   Japan  2021                    1.000000                       245862

# %% [markdown]
# ## **Travel restriction and number or tourists**

# %%
# International Travel Control by country
# 0: No policy
# 1: Screening travellers
# 2: 2 weeks quarantine for travellers from high risk regions
# 3: Ban any travellers from high risk countries
# 4: Close border (No foreigners enter the country)
us2020ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "United States")].iloc[:366]["international_travel_controls"].mean()
us2021ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "United States")].iloc[366:731]["international_travel_controls"].mean()
us2022ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "United States")].iloc[731:1096]["international_travel_controls"].mean()

canada2020ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "Canada")].iloc[:366]["international_travel_controls"].mean()
canada2021ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "Canada")].iloc[366:731]["international_travel_controls"].mean()
canada2022ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "Canada")].iloc[731:1096]["international_travel_controls"].mean()

mexico2020ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "Mexico")].iloc[:366]["international_travel_controls"].mean()
mexico2021ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "Mexico")].iloc[366:731]["international_travel_controls"].mean()
mexico2022ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "Mexico")].iloc[731:1096]["international_travel_controls"].mean()

brazil2020ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "Brazil")].iloc[:366]["international_travel_controls"].mean()
brazil2021ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "Brazil")].iloc[366:731]["international_travel_controls"].mean()
brazil2022ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "Brazil")].iloc[731:1096]["international_travel_controls"].mean()

china2020ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "China")].iloc[:366]["international_travel_controls"].mean()
china2021ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "China")].iloc[366:731]["international_travel_controls"].mean()
china2022ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "China")].iloc[731:1096]["international_travel_controls"].mean()

japan2020ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "Japan")].iloc[:366]["international_travel_controls"].mean()
japan2021ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "Japan")].iloc[366:731]["international_travel_controls"].mean()
japan2022ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "Japan")].iloc[731:1096]["international_travel_controls"].mean()

korea2020ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "South Korea")].iloc[:366]["international_travel_controls"].mean()
korea2021ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "South Korea")].iloc[366:731]["international_travel_controls"].mean()
korea2022ITC = rawInternationalTravelControlData.loc[(
    rawInternationalTravelControlData["Entity"] == "South Korea")].iloc[731:1096]["international_travel_controls"].mean()

itpDataFrame = pd.DataFrame({
    "Country": ["USA", "USA",
                "Canada", "Canada",
                "Mexico", "Mexico",
                "Korea", "Korea",
                "Japan", "Japan"],
    "Year": [2020, 2021,
             2020, 2021,
             2020, 2021,
             2020, 2021,
             2020, 2021],
    "Internation Travel Policy (avg)": [us2020ITC, us2021ITC,
                                        canada2020ITC, canada2021ITC,
                                        mexico2020ITC, mexico2021ITC,
                                        japan2020ITC, japan2021ITC,
                                        korea2020ITC, korea2021ITC],
    "Number of In-bound Tourists": [us2020Inbound, us2021Inbound,
                                    canada2020Inbound, canada2020Inbound,
                                    mexico2020Inbound, mexico2021Inbound,
                                    korea2020Inbound, korea2021Inbound,
                                    japan2020Inbound, japan2021Inbound]

})
itpDataFrame
# Out:
#   Country  Year  Internation Travel Policy (avg)  Number of In-bound Tourists
# 0     USA  2020                         2.713115                     53556920
# 1     USA  2021                         2.890411                     46344402
# 2  Canada  2020                         3.311475                      5068000
# 3  Canada  2021                         3.128767                      5068000
# 4  Mexico  2020                         1.830601                     51128042
# 5  Mexico  2021                         1.000000                     55301421
# 6   Korea  2020                         2.756831                      2519118
# 7   Korea  2021                         4.000000                       967003
# 8   Japan  2020                         2.415301                      4115828
# 9   Japan  2021                         2.435616                       245862

# %% [markdown]
# ## **Canadian Hotel occupancy rate each months**

# %%
CanadaHotelOccupancyRate = monthlyCanadaHotelInfo.iloc[:, 2]

def getMonths(year):
    year = str(year)
    months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
              "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
    for i in range(12):
        months[i] = year+months[i]
    return months


x = getMonths(0)+getMonths(1)+getMonths(2)
x = x[:32]

def getOccupancies(occupancyList):
    percentageList = []
    for i in range(len(occupancyList)):
        theStr = occupancyList[i][1:]
        theStr = theStr.strip("%")
        percentageList.append(float(theStr))
    return percentageList


y = getOccupancies(CanadaHotelOccupancyRate)

fig, inboundGraph = plt.subplots(figsize=(20, 4))
plt.title("Canada Hotel Occupancy Rate")
inboundGraph.set_xlabel("202x year, month")
inboundGraph.set_ylabel("room occupancy")
inboundGraph.plot(x, y)

# %% [markdown]
# # Global unemployment in 2019 and 2020
# According to the displayed graph, the COVID-19 pandemic has resulted in significant job losses globally, with youth and women being disproportionately affected. In 2020, the global unemployment rate has increased by 1.1 % compare to year 2019, reaching 6.5%, and the number of unemployed individuals increased by 33 million to reach 220 million. Additionally, 81 million individuals withdrew from the labour market altogether. Unemployment rates in Latin America and the Caribbean, as well as in Europe and Northern America, increased by at least 2 %.
#
# Youth and women experienced a greater impact, with employment losses of 8.7 % and 5.0 %, respectively, compared to 3.7% for adults and 3.9 per cent for men. Prior to the pandemic, youth unemployment rates were three times higher than those of adults. During the crisis, women were more likely than men to leave the labour market to care for their children, resulting in further widening of gender disparities in labour force participation rates.

# %%
fig = plt.figure(figsize=(20, 6))
regions = ["North Africa & West Asia",
           "Latin America",
           "Europe & North America",
           "CentralSouthern Asia",
           "subsaharan Africa",
           "Australia & New Zealand",
           "Eastern & Southeast Asia",
           "Oceania"]
unemployment2019 = unemployment["2019"]
unemployment2020 = unemployment["2020"]

regionNames = np.arange(len(regions))

plt.bar(regionNames - 0.2, unemployment2019, 0.4, color='b', label="2019")
plt.bar(regionNames + 0.2, unemployment2020, 0.4, color='r', label="2020")

plt.xticks(regionNames, regions)
plt.xlabel("Regions")
plt.ylabel("Unemployment (%)")
plt.title("Global Unemployment Rate")
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this project, the effects of the COVID-19 pandemic on the tourism industry in six countries—-Brazil, Canada, China, Japan, South Korea and the United States are analyzed. The comparison between pre- and post-Covid 19 pandemic tourism spendings, the contrast between inbound and outbound visitor arrivals and departures in 2019 and 2020 are examined. Additionally, factors that contribute to the decline of the tourism industry, such as the prevalence of facial covering mandates, the global unemployment rate, and the travel restriction policies are discussed.
#
# The findings suggest that the pandemic has had a profound impact on the tourism industry. There is a sharp decrease in the number of visitors, which causes the decline of tourism earnings. The closure of schools and workplaces may be the important reason that led to job losses, which has affected people's ability to finance their travel plans. Because of the reuqirements of wearing masks and policies of travel restrictions, people are less likely to go traveling, resulting in the reduction of tourism revenues. Thus, it is evident that the tourism industry has been one of the sectors hit the hardest by the pandemic, and the recovery may take some time.
#
# In conclusion, the COVID-19 pandemic has caused severe disruption to the tourism industry worldwide. The analysis of its effects on tourism spending and visitor arrivals, along with the examination of the factors that contribute to the decline of the industry, highlights the challenges that the industry faces in its recovery. The findings of this project provide insights into the recovery of the tourism industry and the strategies that can be implemented to ensure its future growth.
#
#
# ## Limitations
#
# The analysis is limited by the fact that it only considers a limited number of countries, which does not include European countries and mostly focus on North American and Asia because of the availible data we found online. The impact of the pandemic on the tourism industry may vary across different countries and regions, and the analysis may not be representative of the entire industry globally.
#
# ## Areas for further research
#
# Future research could explore the impact of the pandemic on specific segments of the tourism industry, such as business travel, luxury travel, and adventure travel. The analysis could also consider the impact of the pandemic on different types of tourism, such as cultural tourism, eco-tourism, and medical tourism. Moreover, the analysis could explore the long-term impact of the pandemic on the tourism industry and the measures that can be taken to support the recovery of the industry.

# %% [markdown]
# ## Reference
# * Our World in Data(https://ourworldindata.org)
# * OECD website(https://stats.oecd.org)
